# %% [markdown]
# <a href="https://colab.research.google.com/github/leoforner/RPG/blob/main/RPG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Trabalho planilha rpg  combate V1{ vertical-output: true, display-mode: "form" }
class Personagem:
    def __init__(self, nome, classe):
        self.__nome = nome
        self.__classe = classe
        self.__vida = 100
        self.__mana = 50

    def __str__(self):
        return f"{self.__nome}, {self.__classe} ({self.__vida} HP, {self.__mana} MP)"

    def atacar(self):
        print(f"{self.__nome} atacou com um ataque básico!")

    def defender(self):
        print(f"{self.__nome} se defendeu!")

    def usar_habilidade(self, habilidade):
        print(f"{self.__nome} usou a habilidade {habilidade}!")

    def tomar_dano(self, dano):
        self.__vida -= dano
        if self.__vida <= 0:
            print(f"{self.__nome} foi derrotado!")

    def recuperar_vida(self, cura):
        self.__vida = min(self.__vida + cura, 100)

    def recuperar_mana(self, mana):
        self.__mana = min(self.__mana + mana, 50)

    def get_nome(self):
        return self.__nome

    def get_classe(self):
        return self.__classe

    def get_vida(self):
        return self.__vida

    def get_mana(self):
        return self.__mana


class Guerreiro(Personagem):
    def __init__(self, nome):
        super().__init__(nome, "Guerreiro")

    def atacar(self):
        print(f"{self.get_nome()} atacou com um golpe de espada!")

    def defender(self):
        print(f"{self.get_nome()} bloqueou o ataque com o escudo!")

    def usar_habilidade(self, habilidade):
        if habilidade == "Berserk":
            print(f"{self.get_nome()} usou a habilidade Berserk e ficou mais forte!")
            self.recuperar_vida(10)
        elif habilidade == "Grito de Guerra":
            print(f"{self.get_nome()} usou o Grito de Guerra e inspirou seus aliados!")
            self.recuperar_mana(10)
        else:
            super().usar_habilidade(habilidade)


class Mago(Personagem):
    def __init__(self, nome):
        super().__init__(nome, "Mago")

    def atacar(self):
        print(f"{self.get_nome()} lançou uma bola de fogo!")
        self.recuperar_mana(5)

    def defender(self):
        print(f"{self.get_nome()} conjurou um escudo mágico!")
        self.recuperar_mana(5)

    def usar_habilidade(self, habilidade):
        if habilidade == "Teleporte":
            print(f"{self.get_nome()} usou a habilidade Teleporte e desapareceu!")
        elif habilidade == "Cura":
            print(f"{self.get_nome()} usou a habilidade Cura e se curou!")
            self.recuperar_vida(10)
            self.recuperar_mana(10)
        else:
            super().usar_habilidade(habilidade)


# Testando as classes
guerreiro1 = Guerreiro("Conan")
mago1 = Mago("Gandalf")

print(guerreiro1)
print(mago1)

guerreiro1.atacar()
mago1.atacar()

guerreiro1.defender()
mago1.defender()

guerreiro1.usar_habilidade("Berserk")
mago1.usar_habilidade("Cura")

guerreiro1.tomar_dano(50)
mago1.tomar_dano(70)

print(guerreiro1)
print(mago1)
# Out:
# Conan, Guerreiro (100 HP, 50 MP)
# Gandalf, Mago (100 HP, 50 MP)
# Conan atacou com um golpe de espada!
# Gandalf lançou uma bola de fogo!
# Conan bloqueou o ataque com o escudo!
# Gandalf conjurou um escudo mágico!
# Conan usou a habilidade Berserk e ficou mais forte!
# Gandalf usou a habilidade Cura e se curou!
# Conan, Guerreiro (50 HP, 50 MP)
# Gandalf, Mago (30 HP, 50 MP)

# %%
#@title Trabalho planilha rpg V2{ vertical-output: true, display-mode: "form" }


class Personagem:
    def __init__(self, nome, raca, classe, nivel):
        self.nome = nome
        self.raca = raca
        self.classe = classe
        self.nivel = nivel
        self.pontos_de_vida = self.calcular_pv()
        self.modificador_forca = self.calcular_modificador(self.atributos_base[self.raca]["forca"])
        self.modificador_destreza = self.calcular_modificador(self.atributos_base[self.raca]["destreza"])
        self.modificador_constituicao = self.calcular_modificador(self.atributos_base[self.raca]["constituicao"])
        self.modificador_inteligencia = self.calcular_modificador(self.atributos_base[self.raca]["inteligencia"])
        self.modificador_sabedoria = self.calcular_modificador(self.atributos_base[self.raca]["sabedoria"])
        self.modificador_carisma = self.calcular_modificador(self.atributos_base[self.raca]["carisma"])

    # Atributos base de cada raça
 atributos_base = {
    "anao": {"forca": 2, "constituicao": 2, "destreza": -2, "inteligencia": 0, "sabedoria": 0, "carisma": 0},
    "elfo": {"destreza": 2, "inteligencia": 2, "constituicao": -2, "forca": 0, "sabedoria": 0, "carisma": 0},
    "halfling": {"destreza": 2, "carisma": 2, "forca": -2, "constituicao": 0, "inteligencia": 0, "sabedoria": 0},
    "humano": {"forca": 0, "constituicao": 0, "destreza": 0, "inteligencia": 0, "sabedoria": 0, "carisma": 0},
    "meio-elfo": {"forca": 0, "constituicao": 0, "destreza": 0, "inteligencia": 0, "sabedoria": 0, "carisma": 0},
    "meio-orc": {"forca": 2, "constituicao": 2, "carisma": -2, "destreza": 0, "inteligencia": 0, "sabedoria": 0},
    "gnomo": {"inteligencia": 2, "destreza": 2, "forca": -2, "constituicao": 0, "sabedoria": 0, "carisma": 0},
    "draconato": {"forca": 2, "carisma": 1, "destreza": 0, "constituicao": 0, "inteligencia": 0, "sabedoria": 0},
    "tiefling": {"carisma": 2, "inteligencia": 1, "constituicao": -1, "forca": 0, "destreza": 0, "sabedoria": 0}
}


    # Dados base de cada classe
    dados_base = {
        "barbaro": {"dado_vida": 12, "pontos_vida_nivel": 7},
        "bardo": {"dado_vida": 8, "pontos_vida_nivel": 5},
        "clerigo": {"dado_vida": 8, "pontos_vida_nivel": 5},
        "druida": {"dado_vida": 8, "pontos_vida_nivel": 5},
        "feiticeiro": {"dado_vida": 6, "pontos_vida_nivel": 4},
        "guerreiro": {"dado_vida": 10, "pontos_vida_nivel": 6},
        "ladino": {"dado_vida": 8, "pontos_vida_nivel": 5},
        "mago": {"dado_vida": 6, "pontos_vida_nivel": 4},
        "monge": {"dado_vida": 8, "pontos_vida_nivel": 5},
        "paladino": {"dado_vida": 10, "pontos_vida_nivel": 6},
        "patrulheiro": {"dado_vida": 10, "pontos_vida_nivel": 6}
    }

    def calcular_pv(self):
        dados = self.dados_base[self.classe]
        pontos_vida = dados["pontos_vida_nivel"] * self.nivel
        return pontos_vida + dados["dado_vida"]

    def calcular_modificador(self, valor_atributo):
        return (valor_atributo - 10) // 2

    def gerar_ficha(self):
        print("----- FICHA DE PERSONAGEM -----")
        print(f"Nome: {self.nome}")
        print(f"Raça: {self.raca}")
        print(f"Classe: {self.classe}")
        print(f"Nível: {self.nivel}")
        print(f"Pontos de Vida: {self.pontos_de_vida}")
        print(f"Modificador de Força: {self.modificador_forca}")
        print(f"Modificador de Destreza: {self.modificador_destreza}")
        print(f"Modificador de Constituição: {self.modificador_constituicao}")
        print(f"Modificador de Inteligência: {self.modificador_inteligencia}")
        print(f"Modificador de Sabedoria: {self.modificador_sabedoria}")
        print(f"Modificador de Carisma: {self.modificador_carisma}")
        print("------------------------------")

# Criação do personagem
nome = input("Digite o nome do personagem: ")
raca = input("Digite a raça do personagem: ")
classe = input("Digite a classe do personagem: ")
nivel = int(input("Digite o nível do personagem: "))

personagem = Personagem(nome, raca, classe, nivel)
personagem.gerar_ficha()
# Out:
# Digite o nome do personagem: aaaa
# Digite a raça do personagem: anao
# Digite a classe do personagem: mago
# Digite o nível do personagem: 5
# ----- FICHA DE PERSONAGEM -----
# Nome: aaaa
# Raça: anao
# Classe: mago
# Nível: 5
# Pontos de Vida: 26
# Modificador de Força: -4
# Modificador de Destreza: -6
# Modificador de Constituição: -4
# Modificador de Inteligência: -4
# Modificador de Sabedoria: -4
# Modificador de Carisma: -4
# ------------------------------

# %%
#@title Trabalho planilha rpg V3{ vertical-output: true, display-mode: "form" }

import random

class Personagem:
    atributos_base = {
    "anao": {"forca": 2, "constituicao": 2, "destreza": -2, "inteligencia": 0, "sabedoria": 0, "carisma": 0},
    "elfo": {"forca": 0, "constituicao": 0, "destreza": 2, "inteligencia": 0, "sabedoria": 0, "carisma": 0},
    "halfling": {"forca": -2, "constituicao": 0, "destreza": 2, "inteligencia": 0, "sabedoria": 0, "carisma": 0},
    "humano": {"forca": 1, "constituicao": 1, "destreza": 1, "inteligencia": 1, "sabedoria": 1, "carisma": 1},
    "draconato": {"forca": 2, "constituicao": 0, "destreza": 0, "inteligencia": 0, "sabedoria": 0, "carisma": 1},
    "gnomo": {"forca": -2, "constituicao": 0, "destreza": 0, "inteligencia": 2, "sabedoria": 0, "carisma": 0},
    "meio-elfo": {"forca": 0, "constituicao": 0, "destreza": 0, "inteligencia": 0, "sabedoria": 0, "carisma": 2},
    "meio-orc": {"forca": 2, "constituicao": 1, "destreza": 0, "inteligencia": -2, "sabedoria": 0, "carisma": -1},
    "tiefling": {"forca": 0, "constituicao": 0, "destreza": 0, "inteligencia": 1, "sabedoria": 0, "carisma": 2},
    "aarakocra": {"forca": 0, "constituicao": 0, "destreza": 2, "inteligencia": 0, "sabedoria": 1, "carisma": 0},
    "genasi": {"forca": 0, "constituicao": 2, "destreza": 0, "inteligencia": 0, "sabedoria": 0, "carisma": 0},
    "goliath": {"forca": 2, "constituicao": 1, "destreza": 0, "inteligencia": -2, "sabedoria": 0, "carisma": 0},
    "firbolg": {"forca": 1, "constituicao": 0, "destreza": 0, "inteligencia": 0, "sabedoria": 2, "carisma": 0},
    "kenku": {"forca": 0, "constituicao": 0, "destreza": 2, "inteligencia": 0, "sabedoria": 1, "carisma": 0},
    "lizardfolk": {"forca": 0, "constituicao": 0, "destreza": 2, "inteligencia": 0, "sabedoria": 1, "carisma": -1},
    "tabaxi": {"forca": 0, "constituicao": 0, "destreza": 2, "inteligencia": 0, "sabedoria": 0, "carisma": 1},
    "tritao": {"forca": 1, "constituicao": 1, "destreza": 1, "inteligencia": 0, "sabedoria": 0, "carisma": 1},
    "bugbear": {"forca": 2, "constituicao": 1, "destreza": 0, "inteligencia": -1, "sabedoria": 0, "carisma": 0},
    "goblin": {"forca": -2, "constituicao": 1, "destreza": 2, "inteligencia": 0, "sabedoria": 0, "carisma": -1},
    "hobgoblin": {"forca": 0, "constituicao": 2, "destreza": 0, "inteligencia": 1, "sabedoria": 0, "carisma": -1},
    "kobold": {"forca": -2, "constituicao": 0, "destreza": 2, "inteligencia": -1, "sabedoria": 0, "carisma": -1},
    "orc": {"forca": 2, "constituicao": 1, "destreza": 0, "inteligencia": -2, "sabedoria": 0, "carisma": -1},
    "yuan-ti": {"forca": 0, "constituicao": 0, "destreza": 0, "inteligencia": 1, "sabedoria": 0, "carisma": 2}
    }
    atributos_base_list = list(atributos_base.keys())

    dados_base = {
        "barbaro": {"dado_vida": 12},
        "bardo": {"dado_vida": 8},
        "bruxo": {"dado_vida": 8},
        "clerigo": {"dado_vida": 8},
        "druida": {"dado_vida": 8},
        "feiticeiro": {"dado_vida": 6},
        "guerreiro": {"dado_vida": 10},
        "ladino": {"dado_vida": 8},
        "mago": {"dado_vida": 6},
        "monge": {"dado_vida": 8},
        "paladino": {"dado_vida": 10},
        "patrulheiro": {"dado_vida": 10}
    }

    def __init__(self, nome, raca, classe, nivel, força, destreza, constituicao, inteligencia, sabedoria, carisma):
        self.nome = nome
        self.raca = raca
        self.classe = classe
        self.nivel = nivel
        self.atributo_força = força
        self.atributo_destreza = destreza
        self.atributo_constituicao = constituicao
        self.atributo_inteligencia = inteligencia
        self.atributo_sabedoria = sabedoria
        self.atributo_carisma = carisma
        self.modificador_forca = int(self.__calcular_modificador(self.atributo_força) + self.atributos_base[self.raca].get("forca", 0))
        self.modificador_destreza = int(self.__calcular_modificador(self.atributo_destreza) + self.atributos_base[self.raca].get("destreza", 0))
        self.modificador_constituicao = int(self.__calcular_modificador(self.atributo_constituicao) + self.atributos_base[self.raca].get("constituicao", 0))
        self.modificador_inteligencia = int(self.__calcular_modificador(self.atributo_inteligencia) + self.atributos_base[self.raca].get("inteligencia", 0))
        self.modificador_sabedoria = int(self.__calcular_modificador(self.atributo_sabedoria) + self.atributos_base[self.raca].get("sabedoria", 0))
        self.modificador_carisma =int( self.__calcular_modificador(self.atributo_carisma) + self.atributos_base[self.raca].get("carisma", 0))
        self.pontos_de_vida = int(self.__calcular_pv())

    def __calcular_pv(self):
        dados = self.dados_base[self.classe]
        pontos_vida = dados["dado_vida"]
        for i in range(1,self.nivel):
            pontos_vida = pontos_vida + random.randint(1, dados["dado_vida"])
            print(f"rolagem {i}: {pontos_vida}")

        pontos_vida += self.modificador_constituicao * nivel
        return pontos_vida

    def __calcular_modificador(self, valor_atributo):
        return (valor_atributo - 10) // 2

    def gerar_ficha(self):
        print()
        print()
        print("----- FICHA DE PERSONAGEM -----")
        print(f"Nome: {self.nome.capitalize()}")
        print(f"Raça: {self.raca.capitalize()}")
        print(f"Classe: {self.classe.capitalize()}")
        print(f"Nível: {self.nivel}")
        print(f"Pontos de Vida: {self.pontos_de_vida}")
        print(f"Modificador de Força: {self.modificador_forca}")
        print(f"Modificador de Destreza: {self.modificador_destreza}")
        print(f"Modificador de Constituição: {self.modificador_constituicao}")
        print(f"Modificador de Inteligência: {self.modificador_inteligencia}")
        print(f"Modificador de Sabedoria: {self.modificador_sabedoria}")
        print(f"Modificador de Carisma: {self.modificador_carisma}")
        print("------------------------------")
        print()
        print()


def exibir_opcoes(opcoes):
    print("Opções disponíveis:")
    for i, opcao in enumerate(opcoes, 1):
        print(opcao.capitalize(), end=", ")
        if i % 5 == 0:
            print()

    print()
    print()

def verificacao(valor_recebido, possiveis_valores):
    if valor_recebido in possiveis_valores:
        return True

    return False




# Exibindo as opções disponíveis para raça e classe
exibir_opcoes(Personagem.atributos_base.keys())
exibir_opcoes(Personagem.dados_base.keys())

# Solicitando as entradas ao usuário e validando
nome = input("Digite o nome do personagem: ")
raca = input("Digite a raça do personagem: ").lower()
classe = input("Digite a classe do personagem: ").lower()
while True:
    if raca in Personagem.atributos_base and classe in Personagem.dados_base:
        break
    elif raca in Personagem.atributos_base:
        print("Opção inválida. Por favor, digite a classe novamente.")
        classe = input("Digite a classe do personagem: ").lower()
    else:
        print("Opção inválida. Por favor, digite a raça novamente.")
        raca = input("Digite a raça do personagem: ").lower()

nivel = int(input("Digite o nível do personagem: "))

print(f"Você tem os seguintes pontos para distribuir entre os 6 atributos: 15, 14, 13, 12, 10, 8")
print("Escolha qual valor vai para qual atributo")

pontos = [15,14,13,12,10,8]
pontos_gastos = [0,0,0,0,0]
atributos_dic = {
    "força": 0,
    "destreza": 0,
    "constituicao": 0,
    "inteligencia": 0,
    "sabedoria": 0,
    "carisma": 0
}
atributos_list = list(atributos_dic.keys())

for i in range(len(atributos_list)):
    atributos_dic[atributos_list[i]] = int(input(f"{atributos_list[i]}: "))
    teste = True
    teste = verificacao(atributos_dic[atributos_list[i]], pontos)
    teste2 = verificacao(atributos_dic[atributos_list[i]], pontos_gastos)
    while not teste and teste2:
        atributos_dic[atributos_list[i]] = int(input(f"o valor de {atributos_list[i]} está errado, re-insira: "))
        teste = verificacao(atributos_dic[atributos_list[i]], pontos)
        teste2 = verificacao(atributos_dic[atributos_list[i]], pontos_gastos)

    pontos_gastos[i] = atributos_dic[atributos_list[i]]


personagem = Personagem(nome, raca, classe, nivel, atributos_dic["força"], atributos_dic["destreza"], atributos_dic["constituicao"], atributos_dic["inteligencia"], atributos_dic["sabedoria"], atributos_dic["carisma"])
personagem.gerar_ficha()
# Out:
# Opções disponíveis:
# Anao, Elfo, Halfling, Humano, Draconato,
# Gnomo, Meio-elfo, Meio-orc, Tiefling, Aarakocra,
# Genasi, Goliath, Firbolg, Kenku, Lizardfolk,
# Tabaxi, Tritao, Bugbear, Goblin, Hobgoblin,
# Kobold, Orc, Yuan-ti,
#
# Opções disponíveis:
# Barbaro, Bardo, Bruxo, Clerigo, Druida,
# Feiticeiro, Guerreiro, Ladino, Mago, Monge,
# Paladino, Patrulheiro,
#
# Digite o nome do personagem: nfa
# Digite a raça do personagem: anao
# Digite a classe do personagem: bardo
# Digite o nível do personagem: 5
# Você tem os seguintes pontos para distribuir entre os 6 atributos: 15, 14, 13, 12, 10, 8
# Escolha qual valor vai para qual atributo
# força: 15
# destreza: 9
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-57c2a6a4ff29> in <cell line: 154>()
#     153
#     154 for i in range(len(atributos_list)):
# --> 155     atributos_dic[atributos_list[i]] = int(input(f"{atributos_list[i]}: "))
#     156     teste = True
#     157     teste = verificacao(atributos_dic[atributos_list[i]], pontos)
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
